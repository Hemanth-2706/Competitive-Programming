# %% [markdown]
# <div style="padding: 15px;
#             background-color: #f1f1ef;
#             border-radius: 10px;
#             display: flex;
#             align-items: center;
#             gap: 12px;
#             color: #37352f;">
#     <span style="font-size: 32px;">🧩</span>
#     <div>
#         <span style="font-size: 32px;"><b>Arrays</b> Python Lists</span>
#     </div>
# </div>
# <br>
# <div class="alert alert-info"> ℹ️ <b>Tip:</b> Your text here. </div>
# <div class="alert alert-warning"> ⚠️ <b>Note:</b> Your text here. </div>
# <div class="alert alert-success"> ✅ <b>Success:</b> Your text here. </div>
# <div class="alert alert-danger"> 🚫 <b>Warning:</b> Your text here. </div>
# <br>
# <div style="padding: 15px;
#             background-color: #f1f1ef;
#             border-radius: 10px;
#             display: flex;
#             align-items: center;
#             gap: 12px;
#             color: #37352f;">
#     <span style="font-size: 24px;">💡</span>
#     <div>
#         <b>Pro Tip:</b> This is a Notion-style callout in a Jupyter Notebook.
#     </div>
# </div>
